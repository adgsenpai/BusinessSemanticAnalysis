# %%
import pandas
import search.searchengine as se

df = pandas.DataFrame.from_dict(se.search('game'))
df
# Out:
#        id                                 name  \
# 0     807                                 Game
# 1  987740                             GameMine
# 2  851931                           Gameoflife
# 3    1117                             BT Games
# 4  748956  Askari Lodge & Plumari Game Reserve
# 5  988229                              Game 4U
# 6  759183            Tala Private Game Reserve
# 7  784671  African Explorer Private Game Lodge
# 8  941597                     Mbizi Game Lodge
# 9  924609     Cradle Moon Lakeside Game Lodge
#
#                                   slug     status  accepted_invites_count  \
# 0                                 game     ACTIVE                       1
# 1                             gamemine     ACTIVE                       2
# 2                           gameoflife  SUSPENDED                       0
# 3                             bt-games  SUSPENDED                       0
# ...
